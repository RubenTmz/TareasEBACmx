# %%
from pymongo import MongoClient

client = MongoClient('mongodb+srv://Ruben:1234@cluster0.bdclpw7.mongodb.net/')

# %%
filter={
    'name': 'cairdin'
}

result = client['Tweets']['twe'].find(
  filter=filter
)

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('69127de893bb6b59bc3eaa25'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'neutral',
#     'airline_sentiment_confidence': 1.0,
#     'name': 'cairdin',
#     'retweet_count': 0,
#     'text': '@VirginAmerica What @dhepburn said.',
#     'tweet_created': '2015-02-24 11:35:52 -0800',
#     'tweet_id': 570306133677760513,
#     'user_timezone': 'Eastern Time (US & Canada)'}

# %%
filter={
    'user_timezone': 'Atlantic Time (Canada)'
}

result = client['Tweets']['twe'].find(
  filter=filter
)

# %%
pp = pprint.PrettyPrinter(indent=4)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('69127de893bb6b59bc3eaa37'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'positive',
#     'airline_sentiment_confidence': 1.0,
#     'name': 'thebrandiray',
#     'retweet_count': 0,
#     'text': 'I ❤️ flying @VirginAmerica. ☺️👍',
#     'tweet_created': '2015-02-24 09:15:00 -0800',
#     'tweet_id': 570270684619923457,
#     'tweet_location': 'Somewhere celebrating life. ',
#     'user_timezone': 'Atlantic Time (Canada)'}
# {   '_id': ObjectId('69127de893bb6b59bc3eaa42'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'neutral',
#     'airline_sentiment_confidence': 0.615,
#     'name': 'TenantsUpstairs',
#     'negativereason_confidence': 0.0,
#     'retweet_count': 0,
#     'text': '@VirginAmerica LAX to EWR - Middle seat on a red eye. Such a noob '
#             'maneuver. #sendambien #andchexmix',
#     'tweet_coord': [33.94540417, -118.4062472],
#     'tweet_created': '2015-02-23 23:34:30 -0800',
# ...

# %%
filter={
    'airline_sentiment': "positive"
}

result = client['Tweets']['twe'].find(
  filter=filter
)

pp = pprint.PrettyPrinter(indent=4)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('69127de893bb6b59bc3eaa26'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'positive',
#     'airline_sentiment_confidence': 0.3486,
#     'name': 'jnardino',
#     'negativereason_confidence': 0.0,
#     'retweet_count': 0,
#     'text': "@VirginAmerica plus you've added commercials to the experience... "
#             'tacky.',
#     'tweet_created': '2015-02-24 11:15:59 -0800',
#     'tweet_id': 570301130888122368,
#     'user_timezone': 'Pacific Time (US & Canada)'}
# {   '_id': ObjectId('69127de893bb6b59bc3eaa2b'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'positive',
#     'airline_sentiment_confidence': 0.6745,
#     'name': 'cjmcginnis',
#     'negativereason_confidence': 0.0,
#     'retweet_count': 0,
#     'text': '@VirginAmerica yes, nearly every time I fly VX this “ear worm” '
#             'won’t go away :)',
#     'tweet_created': '2015-02-24 11:13:57 -0800',
#     'tweet_id': 570300616901320704,
# ...

# %%
filter={
    'negativereason': "Bad Flight"
}

result = client['Tweets']['twe'].find(
  filter=filter
)

pp = pprint.PrettyPrinter(indent=4)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('69127de893bb6b59bc3eaa28'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'negative',
#     'airline_sentiment_confidence': 1.0,
#     'name': 'jnardino',
#     'negativereason': 'Bad Flight',
#     'negativereason_confidence': 0.7033,
#     'retweet_count': 0,
#     'text': "@VirginAmerica it's really aggressive to blast obnoxious "
#             '"entertainment" in your guests\' faces &amp; they have little '
#             'recourse',
#     'tweet_created': '2015-02-24 11:15:36 -0800',
#     'tweet_id': 570301031407624196,
#     'user_timezone': 'Pacific Time (US & Canada)'}
# {   '_id': ObjectId('69127de893bb6b59bc3eaa36'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'negative',
#     'airline_sentiment_confidence': 1.0,
#     'name': 'heatherovieda',
#     'negativereason': 'Bad Flight',
#     'negativereason_confidence': 1.0,
#     'retweet_count': 0,
# ...

# %%
filter={
  'user_timezone': "Eastern Time (US & Canada)",
  'airline': "Virgin America"
}

result = client['Tweets']['twe'].find(
  filter=filter
)

pp = pprint.PrettyPrinter(indent=4)

for doc in result:
    pp.pprint(doc)
# Out:
# {   '_id': ObjectId('69127de893bb6b59bc3eaa25'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'neutral',
#     'airline_sentiment_confidence': 1.0,
#     'name': 'cairdin',
#     'retweet_count': 0,
#     'text': '@VirginAmerica What @dhepburn said.',
#     'tweet_created': '2015-02-24 11:35:52 -0800',
#     'tweet_id': 570306133677760513,
#     'user_timezone': 'Eastern Time (US & Canada)'}
# {   '_id': ObjectId('69127de893bb6b59bc3eaa2e'),
#     'airline': 'Virgin America',
#     'airline_sentiment': 'positive',
#     'airline_sentiment_confidence': 1.0,
#     'name': 'YupitsTate',
#     'retweet_count': 0,
#     'text': "@VirginAmerica it was amazing, and arrived an hour early. You're "
#             'too good to me.',
#     'tweet_created': '2015-02-24 10:53:27 -0800',
#     'tweet_id': 570295459631263746,
#     'tweet_location': 'Los Angeles',
#     'user_timezone': 'Eastern Time (US & Canada)'}
# {   '_id': ObjectId('69127de893bb6b59bc3eaa2f'),
# ...
