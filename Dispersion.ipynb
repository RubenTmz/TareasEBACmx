# %%
import pandas as pd
import numpy as np
import os
import plotly.express as px

# %%
df = pd.read_csv('C:/Users/Rubén/Documents/DATA ANALIST/netflix_titles.csv')
df.sample(5)
# Out:
#       Unnamed: 0 show_id   type                            title  \
# 6164        6164   s6165  Movie                 Anger Management
# 6642        6642   s6643  Movie      Dragonheart 3: The Sorcerer
# 142          142    s143  Movie                  Freedom Writers
# 3559        3559   s3560  Movie  Dave Chappelle: Sticks & Stones
# 1835        1835   s1836  Movie      I Am Vengeance: Retaliation
#
#                  director                                               cast  \
# 6164          Peter Segal  Adam Sandler, Jack Nicholson, Marisa Tomei, Lu...
# 6642         Colin Teague  Julian Morris, Tamzin Merchant, Ben Kingsley, ...
# 142   Richard LaGravenese  Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
# 3559          Stan Lathan                                     Dave Chappelle
# 1835          Ross Boyask  Stu Bennett, Vinnie Jones, Mark Griffin, Katri...
#
#                      country         date_added  release_year rating duration  \
# ...

# %%
df = df.drop(columns=['Unnamed: 0'])
df['duration_num'] = df['duration_num'].round().astype(int)

# %%
df_movies_year = df.groupby('release_year').size().rename('movies').reset_index()
df_movies_year
# Out:
#     release_year  movies
# 0           1925       1
# 1           1942       2
# 2           1943       3
# 3           1944       3
# 4           1945       4
# ..           ...     ...
# 69          2017    1032
# 70          2018    1147
# 71          2019    1030
# 72          2020     953
# 73          2021     592
#
# [74 rows x 2 columns]

# %%
fig = px.bar(df_movies_year, x = 'release_year', y= 'movies', title= 'Series y Peliculas por año')
fig.show()

# %%
df['num_words_title'] = df ['title'].str.split().str.len()
df[['num_words_title']].sample(5)
# Out:
#       num_words_title
# 8054                2
# 8187                3
# 6492                4
# 8022                5
# 1096                9

# %%
df[['release_year','num_words_title']].sample(5)
# Out:
#       release_year  num_words_title
# 6214          2017                2
# 2521          2019                4
# 3060          2020                2
# 166           1984                6
# 4892          2015                3

# %%
df_corr = df[['release_year', 'duration_num', 'num_words_title']].corr()

# %%
fig = px.imshow(df_corr,text_auto=True)
fig.show()

# %%
# Facet charts
fig = px.strip(df[df['release_year'] > 2015], x="duration_num", y="num_words_title", color="type", facet_col="release_year")
fig.show()
# Cuatro dimensiones en una
